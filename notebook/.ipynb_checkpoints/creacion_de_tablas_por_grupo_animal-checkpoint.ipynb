# %%
import pandas as pd 
import numpy as np

# %%
pip install unidecode
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from unidecode import unidecode

# %%
data = pd.read_csv('../Data/animales-peligro-extincion.csv')

# %%
data
# Out:
#      animal_id          nombre_cientifico   grupo/animal  familia  \
# 0        12397       Limoniscus violaceus  INVERTEBRADOS  INSECTA
# 1        11397     Pimelia granulicollis   INVERTEBRADOS  INSECTA
# 2        68797  Rhopalomesites euphorbiae  INVERTEBRADOS  INSECTA
# 3        32345              Euchloe bazae  INVERTEBRADOS  INSECTA
# 4        11818       Maculinea nausithous  INVERTEBRADOS  INSECTA
# ..         ...                        ...            ...      ...
# 498      20093      Hyperoodon ampullatus      MAMÍFEROS  CETACEA
# 499      20095    Mesoplodon densirostris      MAMÍFEROS  CETACEA
# 500      20096       Mesoplodon europaeus      MAMÍFEROS  CETACEA
# 501      20098           Mesoplodon mirus      MAMÍFEROS  CETACEA
# 502      20099        Ziphius cavirostris      MAMÍFEROS  CETACEA
#
#                 tipo                              Nombre común  \
# 0         Coleoptera                        Escarabajo resorte
# ...

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#      animal_id          nombre_cientifico   grupo/animal  familia  \
# 0        12397       Limoniscus violaceus  INVERTEBRADOS  INSECTA
# 1        11397     Pimelia granulicollis   INVERTEBRADOS  INSECTA
# 2        68797  Rhopalomesites euphorbiae  INVERTEBRADOS  INSECTA
# 3        32345              Euchloe bazae  INVERTEBRADOS  INSECTA
# 4        11818       Maculinea nausithous  INVERTEBRADOS  INSECTA
# ..         ...                        ...            ...      ...
# 498      20093      Hyperoodon ampullatus      MAMÍFEROS  CETACEA
# 499      20095    Mesoplodon densirostris      MAMÍFEROS  CETACEA
# 500      20096       Mesoplodon europaeus      MAMÍFEROS  CETACEA
# 501      20098           Mesoplodon mirus      MAMÍFEROS  CETACEA
# 502      20099        Ziphius cavirostris      MAMÍFEROS  CETACEA
#
#                 tipo                              Nombre común  \
# 0         Coleoptera                        Escarabajo resorte
# ...

# %%
data['grupo/animal'].unique()
# Out:
# array(['INVERTEBRADOS', 'ANFIBIOS', 'REPTILES', 'AVES', 'MAMÍFEROS'],
#       dtype=object)

# %%
data_1 = data.loc[data['grupo/animal'] == 'MAMÍFEROS']

# %%
data_1.reset_index(drop=True, inplace=True)

# %%
data_1
# Out:
#     animal_id           nombre_cientifico grupo/animal         familia  \
# 0       10669           Atelerix algirus     MAMÍFEROS  ERINACEOMORPHA
# 1       10948       Crocidura canariensis    MAMÍFEROS    SORICOMORPHA
# 2       12059          Galemys pyrenaicus    MAMÍFEROS    SORICOMORPHA
# 3       11230        Rhinolophus euryale     MAMÍFEROS      CHIROPTERA
# 4       11264  Rhinolophus ferrumequinum     MAMÍFEROS      CHIROPTERA
# ..        ...                         ...          ...             ...
# 68      20093       Hyperoodon ampullatus    MAMÍFEROS         CETACEA
# 69      20095     Mesoplodon densirostris    MAMÍFEROS         CETACEA
# 70      20096        Mesoplodon europaeus    MAMÍFEROS         CETACEA
# 71      20098            Mesoplodon mirus    MAMÍFEROS         CETACEA
# 72      20099         Ziphius cavirostris    MAMÍFEROS         CETACEA
#
#                tipo                           Nombre común  \
# ...

# %%
data_1['nombre_cientifico'].unique()
# Out:
# array(['Atelerix algirus ', 'Crocidura canariensis', 'Galemys pyrenaicus',
#        'Rhinolophus euryale ', 'Rhinolophus ferrumequinum ',
#        'Rhinolophus hipposideros', 'Rhinolophus mehelyi ',
#        'Barbastella barbastellus',
#        'Eptesicus isabellinus(antes E. serotinus)', 'Eptesicus serotinus',
#        'Hypsugo savii', 'Myotis alcathoe (= M. mystacinus)',
#        'Myotis bechsteinii ', 'Myotis blythii ', 'Myotis capaccinii',
#        'Myotis daubentonii', 'Myotis emarginatus  ', 'Myotis myotis ',
#        'Myotis mystacinus ', 'Myotis nattereri (=M. escalerai)',
#        'Myotis punicus', 'Nyctalus lasiopterus ', 'Nyctalus leisleri',
#        'Nyctalus noctula  ', 'Pipistrellus kuhlii',
#        'Pipistrellus maderensis', 'Pipistrellus nathusii',
#        'Pipistrellus pipistrellus',
#        'Pipistrellus pygmaeus (antes P. pipistrellus)',
#        'Plecotus auritus', 'Plecotus austriacus',
#        'Plecotus macrobullaris', 'Plecotus teneriffae',
# ...

# %%
data_1 = data_1.applymap(lambda x: unidecode(x) if isinstance(x, str) else x)

# %%
data_5 = data_5.applymap(lambda x: unidecode(x) if isinstance(x, str) else x)

# %%
#data_1.to_csv('MAMÍFEROS-peligro-extincion.csv', index=False)

# %%
data_2 = data.loc[data['grupo/animal'] == 'INVERTEBRADOS']

# %%
data_2.reset_index(drop=True, inplace=True)

# %%
#data_2.to_csv('INVERTEBRADOS-peligro-extincion.csv', index=False)

# %%
data_3 = data.loc[data['grupo/animal'] == 'ANFIBIOS']

# %%
data_2.reset_index(drop=True, inplace=True)

# %%
#data_3.to_csv('ANFIBIOS-peligro-extincion.csv', index=False)

# %%
data_4 = data.loc[data['grupo/animal'] == 'REPTILES']

# %%
data_4.reset_index(drop=True, inplace=True)

# %%
#data_4.to_csv('REPTILES-peligro-extincion.csv', index=False)

# %%
data_5 = data.loc[data['grupo/animal'] == 'AVES']

# %%
data_5.reset_index(drop=True, inplace=True)

# %%
#data_5.to_csv('AVES-peligro-extincion.csv', index=False)
